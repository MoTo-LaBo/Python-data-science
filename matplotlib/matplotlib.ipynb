# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# #### %matplotlib inline　:　マジックコマンド　/ jupyter に対してのコマンド　この　Note 上でグラフを描画できるようになる

# %% [markdown]
# ### plt.plot()

# %%
x = [1, 2, 3, 4, 5]
# y = [1, 4, 9, 16, 25]
y = np.array(x)**2
plt.plot(x, y)

# %%
x = [1, 2, 3, 4, 5]
# y = [1, 4, 9, 16, 25]
y = np.array(x)**2
plt.plot(y)

# %% [markdown]
# - 引数は　y　だけ。　x　の値いには　y　の　index　が入る

# %% [markdown]
# ### シグモイド関数を描画する
# $$S(x)=\frac{1}{1+{e}^{-x}}$$
#
#
# - *data science で頻繁に出てくる*
#     - 1　に寄ったり　0　に寄ったりする事で判定の時に使用しやすい
#         - 何か値に対して確率的に　label　をふる関数になる

# %%
x = np.linspace(-10, 10, 100)  # 数式で横軸を作成する時はよく linspace() を用いる
z = 1/(1+np.exp(-x))  # シグモイド関数
plt.plot(x, z)

# %%
df = pd.DataFrame({'a': [1, 2, 3, 4, 5, 6],
                 'b': [10, 15, 40, 100, 200, 400]})

# %%
df
# Out:
#    a    b
# 0  1   10
# 1  2   15
# 2  3   40
# 3  4  100
# 4  5  200
# 5  6  400

# %%
plt.plot(df['a'], df['b'])

# %%
plt.plot('a', 'b', data=df)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: Second argument 'b' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(df['b']) # 横軸が　Series の index になるので注意する

# %% [markdown]
# ## 装飾(style)

# %%
plt.plot(x, z, 'r')

# %%
plt.plot(x, z, 'g')

# %%
plt.plot(x, z, 'y')

# %%
plt.plot(x, z, 'g--', linewidth=5)

# %%
plt.plot(x, z,
         color='red',
        lw=3,
        ls='--',
        marker='o',
        markersize=10,
        markerfacecolor='yellow',
        markeredgecolor='green',
        markeredgewidth=2,
        alpha=0.3)  # 透明度

# %% [markdown]
# ## 付属情報を付ける

# %%
plt.plot(x, z, label='sigmoid')
plt.plot(x, z*2, label='sigmoid * 2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sigmoid(x)')
plt.legend(loc=4)
plt.xticks([1, 2, 3], rotation=20)
plt.yticks([0, 0.5, 1], rotation=20)
# Out:
# ([<matplotlib.axis.YTick at 0x7fa7b4eb4690>,
#   <matplotlib.axis.YTick at 0x7fa7b4eaed90>,
#   <matplotlib.axis.YTick at 0x7fa7b4ea1e90>],
#  <a list of 3 Text yticklabel objects>)
