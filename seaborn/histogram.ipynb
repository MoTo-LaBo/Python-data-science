# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
# %matplotlib inline
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### ヒストグラム　:　sns.distplot( )

# %%
df = pd.read_csv('../pandas/dataset/tmdb_5000_movies.csv')
sns.distplot(df['vote_count'], norm_hist=False, kde=False)

# %% [markdown]
# ### *確率密度関数　(probability density function : PDF)*
#     - 確率密度関数がわかると, 確立変数がある値の範囲を取る確率が求められる
#
#
# ### **68 - 95 - 99.7rule**
# - **正規分布では**
#     - 平均から　**± １**　標準偏差には約　**68%**　のデータが　$$\mu-\sigma,  \mu+\sigma$$
#     - 平均から　**± 2**　標準偏差には約　**95%**　のデータが　$$\mu-2\sigma,  \mu+2\sigma$$
#     - 平均から　**± 3**　標準偏差には約　**99%**　のデータが　$$\mu-3\sigma,  \mu+3\sigma$$
#         - 含まれるという経験則がある
#
#
# #### <u>*カーネル密度推定( kernel density estimation　:　KDE )*</u>
# - **確立密度関数を推定する１つの方法**

# %%
fn = r'pdf.png'
img = cv2.imread(fn)
# plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.xticks(ticks=[])
plt.yticks(ticks=[])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
sns.set()
sns.distplot(df['vote_count'])
